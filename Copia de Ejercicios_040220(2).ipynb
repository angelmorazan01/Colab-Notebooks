# %% [markdown]
# # Ejercicios 04/02/2020
#
# Num. de cuenta:

# %% [markdown]
# **Ejercicio 1:** Escriba 3 maneras distintas de importar el módulo de `SymPy`:

# %%
import sympy

# %% [markdown]
# __Ejercicio 2:__ ¿Cuál es la diferencia entre `arange` y `linspace`? Da un ejemplo de como usar cada uno.

# %% [markdown]
# **Ejercicio 3:** Defina variabes $a$, $n$ y $x$ con valores -1, 0 y 0.5, respectivamente y realice las siguientes operaciones:
#
# 1. $a + n + x$
# 2. $x - a$
# 3. $a \cdot n \cdot x$
# 4. $n \div x$
# 5. $x^n$

# %% [markdown]
# **Ejercicio 4:** Defina la variable $palabra$ con valor '*Geometria Analitica 2*' y extraiga los siguientes valores:
#
# 1. Geometria 2
# 2. Analitica
# 3. 2

# %% [markdown]
# **Ejercicio 5:** Guarde como elementos de una lista cada uno de los valores extraídos en el ejercicio anterior.

# %% [markdown]
# __Ejercicio 6:__ Grafica las siguientes funciones en un solo `plot`. Fije el dominio adecuado para cada función y ajuste los tamaños de paso para que NO sobresalga una función más que las restantes. Agregue las leyendas al plano que indiquen a que función corresponde cada gráfica.
#
#
# 1.   $y = x^3 $
# 2.   $y = cos(x^2) $
# 3.   $y = \sqrt{x+1}$

# %%
import matplotlib.pyplot as mplot
import numpy as np

x1 = np.arange(-1.5, 1.5, 0.01)
x2 = np.arange(-2*np.pi, 2*np.pi, 0.01)
x3 = np.arange(0, 6, 0.01)

y1= x**3
y2=np.cos(x**2)
y3=np.sqrt (x+1)

mplot.plot (x1,y1)
mplot.plot (x2,y2)
mplot.plot (x3,y3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-dcd6e1b553b5> in <module>()
#      10 y3=np.sqrt (x+1)
#      11
# ---> 12 mplot.plot (x1,y1)
#      13 mplot.plot (x2,y2)
#      14 mplot.plot (x3,y3)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# ...

# %% [markdown]
# __Ejercicio 7:__ Defina dos arreglos $A,B$ en `Numpy` de tamaño $3\times3$ y realice las operaciones siguientes:
#
#
# 1.   $A-B$
# 2.   $A*B$
# 3.   $AB$ #Multiplicación de matrices
# 4.   $A^T$ #Transpuesta de A
# 5.   $B^-1$ #Inversa de B

# %% [markdown]
# **Ejercicio 8:** Resuelva el siguiente sistema de ecuaciones lineales:
#
# $$
# \left(
#             \begin{array}{rr}
#                 2 & 3 \\
#                 1 & -1 \\
#             \end{array}
#         \right)
#         \left(
#             \begin{array}{c}
#                 x_{1} \\
#                 x_{2} \\
#             \end{array}
#         \right)
#             =
#         \left(
#             \begin{array}{r}
#                 18 \\
#                 3 \\
#             \end{array}
#         \right).
# $$
